# %% [markdown]
# # BHARAT INTERN

# %% [markdown]
# # VIRTUAL INTERNSHIP ON MACHINE LEARNING

# %% [markdown]
# # 1. House Price Prediction

# %%
#Importing the required libraries :

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset :

df = pd.read_csv(r"C:\Users\pawan\OneDrive\Desktop\house_data.csv")

# %%
# FIRST 10 ROWS OF THE DATASET

df.head(10)
# Out:
#    id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   1  221900.0       3.0       1.00       1180.0    5650.0     1.0
# 1   2  538000.0       3.0       2.25       2570.0    7242.0     2.0
# 2   3  180000.0       2.0       1.00        770.0   10000.0     1.0
# 3   4  604000.0       4.0       3.00       1960.0    5000.0     1.0
# 4   5  510000.0       3.0       2.00       1680.0    8080.0     1.0
# 5   6  257500.0       3.0       2.25       1715.0    6819.0     2.0
# 6   7  291850.0       3.0       1.50       1060.0    9711.0     1.0
# 7   8  229500.0       3.0       1.00       1780.0    7470.0     1.0
# 8   9  323000.0       3.0       2.50       1890.0    6560.0     2.0
# 9  10  662500.0       3.0       2.50       3560.0    9796.0     1.0
#
#    condition  yr_built
# 0        3.0    1955.0
# 1        3.0    1951.0
# 2        3.0    1933.0
# 3        5.0    1965.0
# 4        3.0    1987.0
# 5        3.0    1995.0
# 6        3.0    1963.0
# 7        3.0    1960.0
# ...

# %%
# COLUMNS :

df.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'yr_built'],
#       dtype='object')

# %%
# SIZE OF THE DATASET 

df.shape
# Out:
# (499, 9)

# %% [markdown]
# **As we can see our dataset has 499 rows and 13 columns.**

# %%
# DATA TYPES OF THE COLUMNS OF THE DATASET

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           499 non-null    int64
#  1   price        498 non-null    float64
#  2   bedrooms     498 non-null    float64
#  3   bathrooms    498 non-null    float64
#  4   sqft_living  498 non-null    float64
#  5   sqft_lot     498 non-null    float64
#  6   floors       498 non-null    float64
#  7   condition    498 non-null    float64
#  8   yr_built     498 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 35.2 KB

# %%
# CHECKING FOR NULL VALUES

df.isnull().sum()
# Out:
# id             0
# price          1
# bedrooms       1
# bathrooms      1
# sqft_living    1
# sqft_lot       1
# floors         1
# condition      1
# yr_built       1
# dtype: int64

# %%
# REMOVAL OF DUPLICATE VALUE 

counter = 0
rs,cs = df.shape

df.drop_duplicates(inplace=True)

if df.shape==(rs,cs):
    print('\n\033[1mInference:\033[0m The dataset doesn\'t have any duplicates')
else:
    print(f'\n\033[1mInference:\033[0m Number of duplicates dropped/fixed ---> {rs-df.shape[0]}')
# Out:
# Inference: The dataset doesn't have any duplicates

# %% [markdown]
# **No null values present our dataset.**

# %%
# CONVERTING ALL OUR CATEGORICAL DATA COLUMNS TO NUMERIC FORM

from sklearn.preprocessing import LabelEncoder
categ = ["id","price","bedrooms","bathrooms","sqft_living","sqft_lot","floors","condition","yr_built"]

# Encode Categorical Columns
le = LabelEncoder()
df[categ] = df[categ].apply(le.fit_transform)

# %%
# AFTER CONVERTING OUR DATASET LOOKS LIKE THIS ...

df.head()
# Out:
#    id  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0   0     28         2          1           34       102       0          2
# 1   1    207         2          5          162       151       2          2
# 2   2      7         1          1            6       275       0          2
# 3   3    234         3          8          107        78       0          4
# 4   4    194         2          4           81       195       0          2
#
#    yr_built
# 0        46
# 1        42
# 2        28
# 3        56
# 4        77

# %%
df.plot()
# Out:
# <Axes: >

# %%
# CORRELATION BETWEEN THE COLUMNS

corr = df.corr()
plt.figure(figsize=(12,7))
sns.heatmap(corr,cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
# Spliting The Dataset :
X = df.drop(['price'],axis=1)
y = df['price']

# %%
X
# Out:
#       id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0      0         2          1           34       102       0          2
# 1      1         2          5          162       151       2          2
# 2      2         1          1            6       275       0          2
# 3      3         3          8          107        78       0          4
# 4      4         2          4           81       195       0          2
# ..   ...       ...        ...          ...       ...     ...        ...
# 494  494         1          6           39         9       2          2
# 495  495         3          4          122        55       2          2
# 496  496         2          7          196       373       0          3
# 497  497         1          2           64       104       1          3
# 498  497         6         16          246       439       5          5
#
#      yr_built
# 0          46
# 1          42
# 2          28
# 3          56
# 4          77
# ...

# %%
y
# Out:
# 0       28
# 1      207
# 2        7
# 3      234
# 4      194
#       ...
# 494    190
# 495    273
# 496     85
# 497    239
# 498    348
# Name: price, Length: 499, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# LENGTH OF X_train AND X_test

len(X_train),len(X_test)
# Out:
# (349, 150)

# %% [markdown]
# # Linear Regression :

# %%
# IMPORTING THE MODULE

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# FITTING THE DATA INTO THE MODEL

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# PREDICTING THE OUTCOMES

y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([221.37303803, 122.892678  , 206.16656839, 142.26442607,
#        297.21638503, 146.76021106, 270.73499741, 179.66266447,
#        105.06663974, 271.70991313, 193.63587465, 179.08001829,
#        132.4468059 , 200.46130235, 180.44090548, 159.30726586,
#        246.18246734, 116.57094825,  80.99914397, 102.22355541,
#        112.63156315, 164.56895043, 121.95819558, 193.57850765,
#        135.77599323, 144.095104  , 176.13679516, 114.37339146,
#        106.21542824, 212.23706187,  55.1800261 ,  89.22529747,
#        209.25922622,  79.6148652 , 121.40896031, 207.86772882,
#        117.52330192,  90.68395322, 151.73872983, 187.40266922,
#        199.82491796, 130.27064859, 166.96816009, 138.12962479,
#         84.70946585, 122.44170343, 207.75094295, 215.91650237,
#        228.73197994, 152.17685409,  70.78550703, 345.74688902,
#        209.44914532, 121.99109502,  66.42828003, 148.17169823,
#        232.34512917, 130.83347394, 136.84380967, 115.81931873,
# ...

# %% [markdown]
# # Evaluation :

# %%
from sklearn.metrics import r2_score,mean_absolute_error
score = r2_score(y_test,y_predict)
mae = mean_absolute_error(y_test,y_predict)

# %%
score
# Out:
# 0.5048578255455028

# %%
mae
# Out:
# 56.38529867674009
